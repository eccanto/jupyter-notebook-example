# %%
import pandas

# %%
data_frame = pandas.DataFrame({
    'Mongoose': [6.51, 3.43, 3.00, 3.10, 3.19, 3.24, 3.09, 3.13, 3.17, 3.26, 3.43],
    'TypeORM':  [4.56, 3.48, 3.15, 3.26, 3.09, 3.31, 3.52, 3.31, 3.30, 3.05, 3.03]
})
print(data_frame)
# Out:
#     Mongoose  TypeORM
# 0       6.51     4.56
# 1       3.43     3.48
# 2       3.00     3.15
# 3       3.10     3.26
# 4       3.19     3.09
# 5       3.24     3.31
# 6       3.09     3.52
# 7       3.13     3.31
# 8       3.17     3.30
# 9       3.26     3.05
# 10      3.43     3.03

# %%
print(data_frame.describe().loc[['mean', 'std', 'min', 'max', '50%']])
# Out:
#       Mongoose   TypeORM
# mean  3.504545  3.369091
# std   1.005727  0.426578
# min   3.000000  3.030000
# max   6.510000  4.560000
# 50%   3.190000  3.300000

# %%
plot = data_frame.plot.line()
plot.set_ylabel('seconds')
plot.set_xlabel('iterations')
# Out:
# Text(0.5, 0, 'iterations')
